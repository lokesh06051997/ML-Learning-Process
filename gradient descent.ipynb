# %%
# Parabola Function

import matplotlib.pyplot as plt
def parabola(x):
    return(x**2)+(0.5*x)   
def derivative(x):
    return 2*x + 0.5
         
x = [i * 0.1 for i in range(-10, 11)]
y = [parabola(xi) for xi in x]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Parabola')
# Out:
# Text(0.5, 1.0, 'Parabola')

# %%
# Gradient Descent for Learning rate 0.1

x_k = 0.0
         
# Experiment with these two hyperparameters
learning_rate = 0.1

epochs = 5
         
for i in range(epochs):
#     print("epochs",i)
    gradient = derivative(x_k)
#     print("gradient",gradient)
    x_k = x_k - learning_rate*gradient
#     print("x_k", x_k)
         
print('Estimated minimum %0.2f, %0.2f' % (x_k, parabola(x_k)))
print('Derivative (gradient) %0.2f' % gradient)
         
x = [i * 0.1 for i in range(-10, 11)]
y = [parabola(xi) for xi in x]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x_k, parabola(x_k), 'ro')
line_x = [x_k - 0.5, x_k + 0.5]
print("line_x",line_x)
line_y = [gradient*(xi-x_k)+parabola(x_k) for xi in line_x]
print("line_y",line_y)
plt.plot(line_x, line_y)
plt.title('Parabola')
# Out:
# Estimated minimum -0.17, -0.06
# Derivative (gradient) 0.20
# line_x [-0.66808, 0.33192]
# line_y [-0.1581891136, 0.04661088639999999]
# Text(0.5, 1.0, 'Parabola')

# %%
# Gradient Descent for Learning rate 0.5

x_k = 0.0
         
# Experiment with these two hyperparameters
learning_rate = 0.5

epochs = 5
         
for i in range(epochs):
#     print("epochs",i)
    gradient = derivative(x_k)
#     print("gradient",gradient)
    x_k = x_k - learning_rate*gradient
#     print("x_k", x_k)
         
print('Estimated minimum %0.2f, %0.2f' % (x_k, parabola(x_k)))
print('Derivative (gradient) %0.2f' % gradient)
         
x = [i * 0.1 for i in range(-10, 11)]
y = [parabola(xi) for xi in x]
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x_k, parabola(x_k), 'ro')
line_x = [x_k - 0.5, x_k + 0.5]
print("line_x",line_x)
line_y = [gradient*(xi-x_k)+parabola(x_k) for xi in line_x]
print("line_y",line_y)
plt.plot(line_x, line_y)
plt.title('Parabola')
# Out:
# Estimated minimum -0.25, -0.06
# Derivative (gradient) 0.00
# line_x [-0.75, 0.25]
# line_y [-0.0625, -0.0625]
# Text(0.5, 1.0, 'Parabola')
