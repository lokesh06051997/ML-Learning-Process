# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import model_from_json

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def function(x):
    return 10*x**2 - 5*x - 0.5

x_train = np.random.rand(10000)
y_train = function(x_train)
         
x_test = np.linspace(0, 1, 100)
y_test = function(x_test)

plt.scatter(x_train,y_train,color='r',label='Train')
plt.plot(x_test,y_test,color="b",label="Test")
plt.title =("model plot")
plt.ylabel =("y")
plt.xlabel = ("x")
plt.legend(loc='best')
plt.show()

model = Sequential()
model.add(Dense(units=200, input_dim=1))
model.add(Activation('relu'))
model.add(Dense(units=20))
model.add(Activation('relu'))
model.add(Dense(units=1))

model.compile(loss='mean_squared_error', optimizer=RMSprop())
history = model.fit(x_train, y_train, batch_size=50, epochs=10, verbose=1, validation_data=(x_test, y_test))

from importlib import reload
reload(plt)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model loss")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

y_predictions = model.predict(x_test)

plt.scatter(x_test, y_predictions, label='Predictions', color='blue')
plt.plot(x_test, y_test, label='Test', color='red')
plt.ylabel('y')
plt.xlabel('x')
plt.legend(loc='best')
plt.show()
# Out:
# Epoch 1/10
# 200/200 [==============================] - 1s 4ms/step - loss: 1.2026 - val_loss: 0.2094
# Epoch 2/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0418 - val_loss: 0.0094
# Epoch 3/10
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0053
# Epoch 4/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 5/10
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 6/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 7/10
# 200/200 [==============================] - 0s 2ms/step - loss: 0.0022 - val_loss: 0.0046
# Epoch 8/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 9.4441e-04
# Epoch 9/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 1.0401e-04
# Epoch 10/10
# 200/200 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 5.4985e-05
