# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adadelta
from tensorflow.keras.models import model_from_json

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def function(x):
    return 10*x**2 - 5*x - 0.5

x_train = np.random.rand(10000)
y_train = function(x_train)
         
x_test = np.linspace(0, 1, 100)
y_test = function(x_test)

plt.scatter(x_train,y_train,color='r',label='Train')
plt.plot(x_test,y_test,color="b",label="Test")
plt.title =("model plot")
plt.ylabel =("y")
plt.xlabel = ("x")
plt.legend(loc='best')
plt.show()

model = Sequential()
model.add(Dense(units=200, input_dim=1))
model.add(Activation('relu'))
model.add(Dense(units=20))
model.add(Activation('relu'))
model.add(Dense(units=1))

model.compile(loss='mean_squared_error', optimizer=Adadelta())
history = model.fit(x_train, y_train, batch_size=50, epochs=10, verbose=1, validation_data=(x_test, y_test))

from importlib import reload
reload(plt)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Model loss")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

y_predictions = model.predict(x_test)

plt.scatter(x_test, y_predictions, label='Predictions', color='blue')
plt.plot(x_test, y_test, label='Test', color='red')
plt.ylabel('y')
plt.xlabel('x')
plt.legend(loc='best')
plt.show()
# Out:
# Epoch 1/10
# 200/200 [==============================] - 1s 4ms/step - loss: 2.8854 - val_loss: 2.7636
# Epoch 2/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8701 - val_loss: 2.7494
# Epoch 3/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8545 - val_loss: 2.7340
# Epoch 4/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8374 - val_loss: 2.7189
# Epoch 5/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8230 - val_loss: 2.7060
# Epoch 6/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.8092 - val_loss: 2.6931
# Epoch 7/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.7953 - val_loss: 2.6802
# Epoch 8/10
# 200/200 [==============================] - 0s 2ms/step - loss: 2.7813 - val_loss: 2.6671
# Epoch 9/10
# 200/200 [==============================] - 0s 2ms/step - loss: 2.7672 - val_loss: 2.6540
# Epoch 10/10
# 200/200 [==============================] - 1s 3ms/step - loss: 2.7531 - val_loss: 2.6408
